# %%
from pynwb import NWBFile
from rich import inspect, print

# %%
inspect(NWBFile, methods=True)
# Out:
# ╭───────────────────────────────────────── <class 'pynwb.file.NWBFile'> ──────────────────────────────────────────╮
# │ class NWBFile(*args, **kwargs):                                                                                 │
# │                                                                                                                 │
# │ A representation of an NWB file.                                                                                │
# │                                                                                                                 │
# │                         acquisition = <property object at 0x7ee65a1659e0>                                       │
# │                         all_objects = <property object at 0x7ee671575cb0>                                       │
# │                            analysis = <property object at 0x7ee65a165a30>                                       │
# │                            children = <property object at 0x7ee671575fd0>                                       │
# │                    container_source = <property object at 0x7ee671576110>                                       │
# │                           css_style = <property object at 0x7ee67c5df510>                                       │
# │                     data_collection = <property object at 0x7ee65a1652b0>                                       │
# │                           data_type = <property object at 0x7ee65ab9b4c0>                                       │
# │                             devices = <property object at 0x7ee65a165cb0>                                       │
# │                 ec_electrode_groups = <property object at 0x7ee65a11b3d0>                                       │
# │                       ec_electrodes = <property object at 0x7ee65a11b2e0>                                       │
# │                    electrode_groups = <property object at 0x7ee65a165bc0>                                       │
# │                          electrodes = <property object at 0x7ee65a165440>                                       │
# │                          epoch_tags = <property object at 0x7ee65a11b4c0>                                       │
# │                              epochs = <property object at 0x7ee65a165490>                                       │
# │              experiment_description = <property object at 0x7ee65a164f90>                                       │
# │                        experimenter = <property object at 0x7ee65a164f40>                                       │
# │                              fields = <property object at 0x7ee671575e90>                                       │
# │                    file_create_date = <property object at 0x7ee65a164ef0>                                       │
# │                       ic_electrodes = <property object at 0x7ee65a11b470>                                       │
# │                  icephys_electrodes = <property object at 0x7ee65a165fd0>                                       │
# │     icephys_experimental_conditions = <property object at 0x7ee65a165940>                                       │
# │                   icephys_filtering = <property object at 0x7ee65a11b510>                                       │
# │                 icephys_repetitions = <property object at 0x7ee65a1658a0>                                       │
# │       icephys_sequential_recordings = <property object at 0x7ee65a165800>                                       │
# │     icephys_simultaneous_recordings = <property object at 0x7ee65a165760>                                       │
# │                          identifier = <property object at 0x7ee65a164e00>                                       │
# │                      imaging_planes = <property object at 0x7ee65a165ee0>                                       │
# │                         institution = <property object at 0x7ee65a165030>                                       │
# │                           intervals = <property object at 0x7ee65a166070>                                       │
# │            intracellular_recordings = <property object at 0x7ee65a1656c0>                                       │
# │                       invalid_times = <property object at 0x7ee65a165620>                                       │
# │                           js_script = <property object at 0x7ee67c1ef830>                                       │
# │                            keywords = <property object at 0x7ee65a165080>                                       │
# │                                 lab = <property object at 0x7ee65a1653f0>                                       │
# │                       lab_meta_data = <property object at 0x7ee65a166160>                                       │
# │                            modified = <property object at 0x7ee671575f30>                                       │
# │                             modules = <property object at 0x7ee65a11a890>                                       │
# │                                name = <property object at 0x7ee673f71300>                                       │
# │                           namespace = 'core'                                                                    │
# │                      neurodata_type = 'NWBFile'                                                                 │
# │                               notes = <property object at 0x7ee65a1650d0>                                       │
# │                           object_id = <property object at 0x7ee671575f80>                                       │
# │                             objects = <property object at 0x7ee65a11b330>                                       │
# │                          ogen_sites = <property object at 0x7ee65a165f80>                                       │
# │                              parent = <property object at 0x7ee671576070>                                       │
# │                        pharmacology = <property object at 0x7ee65a165120>                                       │
# │                          processing = <property object at 0x7ee65a165c10>                                       │
# │                            protocol = <property object at 0x7ee65a165170>                                       │
# │                             read_io = <property object at 0x7ee671575e40>                                       │
# │                related_publications = <property object at 0x7ee65a1651c0>                                       │
# │                             scratch = <property object at 0x7ee65a165ad0>                                       │
# │                 session_description = <property object at 0x7ee65a164db0>                                       │
# │                          session_id = <property object at 0x7ee65a164fe0>                                       │
# │                  session_start_time = <property object at 0x7ee65a164e50>                                       │
# │                              slices = <property object at 0x7ee69c046390>                                       │
# │                       source_script = <property object at 0x7ee65a165210>                                       │
# │             source_script_file_name = <property object at 0x7ee65a165260>                                       │
# │                            stimulus = <property object at 0x7ee65a165b70>                                       │
# │                      stimulus_notes = <property object at 0x7ee65a1653a0>                                       │
# │                   stimulus_template = <property object at 0x7ee65a165a80>                                       │
# │                             subject = <property object at 0x7ee65a165580>                                       │
# │                             surgery = <property object at 0x7ee65a165300>                                       │
# │                         sweep_table = <property object at 0x7ee65a1655d0>                                       │
# │           timestamps_reference_time = <property object at 0x7ee65a164ea0>                                       │
# │                              trials = <property object at 0x7ee65a1654e0>                                       │
# │                               units = <property object at 0x7ee65a165530>                                       │
# │                               virus = <property object at 0x7ee65a165350>                                       │
# │                     add_acquisition = def add_acquisition(*args, **kwargs): add_acquisition(nwbdata,            │
# │                                       use_sweep_table=False)                                                    │
# │                        add_analysis = def add_analysis(*args, **kwargs): add_analysis(analysis)                 │
# │                           add_child = def add_child(*args, **kwargs): add_child(child=None)                     │
# │                          add_device = def add_device(*args, **kwargs): add_device(devices)                      │
# │                       add_electrode = def add_electrode(*args, **kwargs): add_electrode(x=None, y=None, z=None, │
# │                                       imp=None, location=None, filtering=None, group=None, id=None, rel_x=None, │
# │                                       rel_y=None, rel_z=None, reference=None, enforce_unique_id=True)           │
# │                add_electrode_column = def add_electrode_column(*args, **kwargs): add_electrode_column(name,     │
# │                                       description, data=[], table=False, index=False, enum=False,               │
# │                                       col_cls=<class 'hdmf.common.table.VectorData'>, check_ragged=True)        │
# │                 add_electrode_group = def add_electrode_group(*args, **kwargs):                                 │
# │                                       add_electrode_group(electrode_groups)                                     │
# │                           add_epoch = def add_epoch(*args, **kwargs): add_epoch(start_time, stop_time,          │
# │                                       tags=None, timeseries=None)                                               │
# │                    add_epoch_column = def add_epoch_column(*args, **kwargs): add_epoch_column(name,             │
# │                                       description, data=[], table=False, index=False, enum=False,               │
# │                                       col_cls=<class 'hdmf.common.table.VectorData'>, check_ragged=True)        │
# │           add_epoch_metadata_column = def add_epoch_metadata_column(self, *args, **kwargs):                     │
# │                                       This method is deprecated and will be removed in future versions. Please  │
# │                                       use :py:meth:`~pynwb.file.NWBFile.add_epoch_column` instead               │
# │                    add_ic_electrode = def add_ic_electrode(self, *args, **kwargs):                              │
# │                                       This method is deprecated and will be removed in future versions. Please  │
# │                                       use :py:meth:`~pynwb.file.NWBFile.add_icephys_electrode` instead          │
# │               add_icephys_electrode = def add_icephys_electrode(*args, **kwargs):                               │
# │                                       add_icephys_electrode(icephys_electrodes)                                 │
# │  add_icephys_experimental_condition = def add_icephys_experimental_condition(*args, **kwargs):                  │
# │                                       add_icephys_experimental_condition(repetitions=None)                      │
# │              add_icephys_repetition = def add_icephys_repetition(*args, **kwargs):                              │
# │                                       add_icephys_repetition(sequential_recordings=None)                        │
# │    add_icephys_sequential_recording = def add_icephys_sequential_recording(*args, **kwargs):                    │
# │                                       add_icephys_sequential_recording(stimulus_type, simultaneous_recordings)  │
# │  add_icephys_simultaneous_recording = def add_icephys_simultaneous_recording(*args, **kwargs):                  │
# │                                       add_icephys_simultaneous_recording(recordings)                            │
# │                   add_imaging_plane = def add_imaging_plane(*args, **kwargs): add_imaging_plane(imaging_planes) │
# │         add_intracellular_recording = def add_intracellular_recording(*args, **kwargs):                         │
# │                                       add_intracellular_recording(electrode=None, stimulus_start_index=None,    │
# │                                       stimulus_index_count=None, stimulus=None,                                 │
# │                                       stimulus_template_start_index=None, stimulus_template_index_count=None,   │
# │                                       stimulus_template=None, response_start_index=None,                        │
# │                                       response_index_count=None, response=None, electrode_metadata=None,        │
# │                                       stimulus_metadata=None, response_metadata=None)                           │
# │           add_invalid_time_interval = def add_invalid_time_interval(*args, **kwargs):                           │
# │                                       add_invalid_time_interval(start_time, stop_time, tags=None,               │
# │                                       timeseries=None)                                                          │
# │            add_invalid_times_column = def add_invalid_times_column(*args, **kwargs):                            │
# │                                       add_invalid_times_column(name, description, data=[], table=False,         │
# │                                       index=False, enum=False, col_cls=<class 'hdmf.common.table.VectorData'>,  │
# │                                       check_ragged=True)                                                        │
# │                   add_lab_meta_data = def add_lab_meta_data(*args, **kwargs): add_lab_meta_data(lab_meta_data)  │
# │                       add_ogen_site = def add_ogen_site(*args, **kwargs): add_ogen_site(ogen_sites)             │
# │               add_processing_module = def add_processing_module(*args, **kwargs):                               │
# │                                       add_processing_module(processing)                                         │
# │                         add_scratch = def add_scratch(*args, **kwargs): add_scratch(data, name=None,            │
# │                                       notes=None, table_description='', description=None)                       │
# │                        add_stimulus = def add_stimulus(*args, **kwargs): add_stimulus(stimulus=None,            │
# │                                       use_sweep_table=False, timeseries=None)                                   │
# │               add_stimulus_template = def add_stimulus_template(*args, **kwargs):                               │
# │                                       add_stimulus_template(timeseries, use_sweep_table=False)                  │
# │                  add_time_intervals = def add_time_intervals(*args, **kwargs): add_time_intervals(intervals)    │
# │                           add_trial = def add_trial(*args, **kwargs): add_trial(start_time, stop_time,          │
# │                                       tags=None, timeseries=None)                                               │
# │                    add_trial_column = def add_trial_column(*args, **kwargs): add_trial_column(name,             │
# │                                       description, data=[], table=False, index=False, enum=False,               │
# │                                       col_cls=<class 'hdmf.common.table.VectorData'>, check_ragged=True)        │
# │                            add_unit = def add_unit(*args, **kwargs): add_unit(spike_times=None,                 │
# │                                       obs_intervals=None, electrodes=None, electrode_group=None,                │
# │                                       waveform_mean=None, waveform_sd=None, waveforms=None, id=None)            │
# │                     add_unit_column = def add_unit_column(*args, **kwargs): add_unit_column(name, description,  │
# │                                       data=[], table=False, index=False, enum=False, col_cls=<class             │
# │                                       'hdmf.common.table.VectorData'>, check_ragged=True)                       │
# │                        all_children = def all_children(self): Get a list of all child objects and their child   │
# │                                       objects recursively.                                                      │
# │                                copy = def copy(self):                                                           │
# │                                       Shallow copy of an NWB file.                                              │
# │                                       Useful for linking across files.                                          │
# │                       create_device = def create_device(*args, **kwargs): create_device(name, description=None, │
# │                                       manufacturer=None)                                                        │
# │              create_electrode_group = def create_electrode_group(*args, **kwargs): create_electrode_group(name, │
# │                                       description, location, device, position=None)                             │
# │       create_electrode_table_region = def create_electrode_table_region(*args, **kwargs):                       │
# │                                       create_electrode_table_region(region, description, name='electrodes')     │
# │                 create_ic_electrode = def create_ic_electrode(self, *args, **kwargs):                           │
# │                                       This method is deprecated and will be removed in future versions. Please  │
# │                                       use :py:meth:`~pynwb.file.NWBFile.create_icephys_electrode` instead       │
# │            create_icephys_electrode = def create_icephys_electrode(*args, **kwargs):                            │
# │                                       create_icephys_electrode(name, device, description, slice=None,           │
# │                                       seal=None, location=None, resistance=None, filtering=None,                │
# │                                       initial_access_resistance=None, cell_id=None)                             │
# │                create_imaging_plane = def create_imaging_plane(*args, **kwargs): create_imaging_plane(name,     │
# │                                       optical_channel, description, device, excitation_lambda, indicator,       │
# │                                       location, imaging_rate=None, manifold=None, conversion=1.0,               │
# │                                       unit='meters', reference_frame=None, origin_coords=None,                  │
# │                                       origin_coords_unit='meters', grid_spacing=None,                           │
# │                                       grid_spacing_unit='meters')                                               │
# │                create_lab_meta_data = def create_lab_meta_data(*args, **kwargs): create_lab_meta_data(name)     │
# │                    create_ogen_site = def create_ogen_site(*args, **kwargs): create_ogen_site(name, device,     │
# │                                       description, excitation_lambda, location)                                 │
# │            create_processing_module = def create_processing_module(*args, **kwargs):                            │
# │                                       create_processing_module(name, description, data_interfaces=None)         │
# │               create_time_intervals = def create_time_intervals(*args, **kwargs): create_time_intervals(name,   │
# │                                       description='experimental intervals', id=None, columns=None,              │
# │                                       colnames=None)                                                            │
# │                     generate_new_id = def generate_new_id(*args, **kwargs): generate_new_id(recurse=True)       │
# │                     get_acquisition = def get_acquisition(*args, **kwargs): get_acquisition(name=None)          │
# │                        get_analysis = def get_analysis(*args, **kwargs): get_analysis(name=None)                │
# │                        get_ancestor = def get_ancestor(*args, **kwargs): get_ancestor(neurodata_type=None)      │
# │                       get_ancestors = def get_ancestors(*args, **kwargs): get_ancestors()                       │
# │                          get_device = def get_device(*args, **kwargs): get_device(name=None)                    │
# │                 get_electrode_group = def get_electrode_group(*args, **kwargs): get_electrode_group(name=None)  │
# │                     get_fields_conf = def get_fields_conf():                                                    │
# │                    get_ic_electrode = def get_ic_electrode(self, *args, **kwargs):                              │
# │                                       This method is deprecated and will be removed in future versions. Please  │
# │                                       use :py:meth:`~pynwb.file.NWBFile.get_icephys_electrode` instead          │
# │               get_icephys_electrode = def get_icephys_electrode(*args, **kwargs):                               │
# │                                       get_icephys_electrode(name=None)                                          │
# │ get_icephys_experimental_conditions = def get_icephys_experimental_conditions(*args, **kwargs):                 │
# │                                       get_icephys_experimental_conditions()                                     │
# │       get_icephys_meta_parent_table = def get_icephys_meta_parent_table(self): Get the top-most table in the    │
# │                                       intracellular ephys metadata table hierarchy that exists in this NWBFile. │
# │             get_icephys_repetitions = def get_icephys_repetitions(*args, **kwargs): get_icephys_repetitions()   │
# │   get_icephys_sequential_recordings = def get_icephys_sequential_recordings(*args, **kwargs):                   │
# │                                       get_icephys_sequential_recordings()                                       │
# │ get_icephys_simultaneous_recordings = def get_icephys_simultaneous_recordings(*args, **kwargs):                 │
# │                                       get_icephys_simultaneous_recordings()                                     │
# │                   get_imaging_plane = def get_imaging_plane(*args, **kwargs): get_imaging_plane(name=None)      │
# │        get_intracellular_recordings = def get_intracellular_recordings(*args, **kwargs):                        │
# │                                       get_intracellular_recordings()                                            │
# │                   get_lab_meta_data = def get_lab_meta_data(*args, **kwargs): get_lab_meta_data(name=None)      │
# │                get_linked_resources = def get_linked_resources(self):                                           │
# │                       get_ogen_site = def get_ogen_site(*args, **kwargs): get_ogen_site(name=None)              │
# │               get_processing_module = def get_processing_module(*args, **kwargs):                               │
# │                                       get_processing_module(name=None)                                          │
# │                         get_read_io = def get_read_io(self): Get the io object used to read this container.     │
# │                         get_scratch = def get_scratch(*args, **kwargs): get_scratch(name, convert=True)         │
# │                        get_stimulus = def get_stimulus(*args, **kwargs): get_stimulus(name=None)                │
# │               get_stimulus_template = def get_stimulus_template(*args, **kwargs):                               │
# │                                       get_stimulus_template(name=None)                                          │
# │                  get_time_intervals = def get_time_intervals(*args, **kwargs): get_time_intervals(name=None)    │
# │                      link_resources = def link_resources(*args, **kwargs): link_resources(herd)                 │
# │                        reset_parent = def reset_parent(self): Reset the parent of this Container to None and    │
# │                                       remove the Container from the children of its parent.                     │
# │                         set_data_io = def set_data_io(self, dataset_name: str, data_io_class:                   │
# │                                       Type[hdmf.data_utils.DataIO], data_io_kwargs: dict = None,                │
# │                                       data_chunk_iterator_class:                                                │
# │                                       Optional[Type[hdmf.data_utils.AbstractDataChunkIterator]] = None,         │
# │                                       data_chunk_iterator_kwargs: dict = None, **kwargs): Apply DataIO object   │
# │                                       to a dataset field of the Container.                                      │
# │                 set_electrode_table = def set_electrode_table(*args, **kwargs):                                 │
# │                                       set_electrode_table(electrode_table)                                      │
# │                        set_modified = def set_modified(*args, **kwargs): set_modified(modified=True)            │
# │                      type_hierarchy = def type_hierarchy():                                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
from datetime import datetime

nwb_test = NWBFile(
        session_description = "test_dataset",
        identifier = "test_id",
        session_start_time = datetime.now(),
        lab = "Zimmer lab",
        institution = "Univie",
        related_publications = "None"
    )
# Out:
# /home/zimuser/anaconda3/envs/scopecontrol/lib/python3.10/site-packages/pynwb/file.py:468: UserWarning: Date is missing timezone information. Updating to local timezone.
#   args_to_set['session_start_time'] = _add_missing_timezone(session_start_time)

# %%
inspect(nwb_test, methods=True)
# Out:
# ╭───────────────────────────────────────── <class 'pynwb.file.NWBFile'> ──────────────────────────────────────────╮
# │ A representation of an NWB file.                                                                                │
# │                                                                                                                 │
# │ ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────╮ │
# │ │ root pynwb.file.NWBFile at 0x139527466928928                                                                │ │
# │ │ Fields:                                                                                                     │ │
# │ │   file_create_date: [datetime.datetime(2024, 12, 4, 14, 22, 19, 530293, tzinfo=tzlocal())]                  │ │
# │ │   identifier: test_id                                                                                       │ │
# │ │   institution: Univie                                                                                       │ │
# │ │   lab: Zimmer lab                                                                                           │ │
# │ │   related_publications: ['None']                                                                            │ │
# │ │   session_description: test_dataset                                                                         │ │
# │ │   session_start_time: 2024-12-04 14:22:19.529389+01:00                                                      │ │
# │ │   timestamps_reference_time: 2024-12-04 14:22:19.529389+01:00                                               │ │
# │ ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                                 │
# │                         acquisition = {}                                                                        │
# │                         all_objects = None                                                                      │
# │                            analysis = {}                                                                        │
# │                            children = ()                                                                        │
# │                    container_source = None                                                                      │
# │                           css_style = '\n        <style>\n            .container-fields {\n                     │
# │                                       font-family: "Open Sans", Arial, sans-serif;\n            }\n             │
# │                                       .container-fields .field-value {\n                color: #00788E;\n       │
# │                                       }\n            .container-fields details > summary {\n                    │
# │                                       cursor: pointer;\n                display: list-item;\n            }\n    │
# │                                       .container-fields details > summary:hover {\n                color:       │
# │                                       #0A6EAA;\n            }\n        </style>\n        '                      │
# │                     data_collection = None                                                                      │
# │                           data_type = 'NWBFile'                                                                 │
# │                             devices = {}                                                                        │
# │                 ec_electrode_groups = {}                                                                        │
# │                       ec_electrodes = None                                                                      │
# │                    electrode_groups = {}                                                                        │
# │                          electrodes = None                                                                      │
# │                          epoch_tags = set()                                                                     │
# │                              epochs = None                                                                      │
# │              experiment_description = None                                                                      │
# │                        experimenter = None                                                                      │
# │                              fields = {                                                                         │
# │                                           'session_description': 'test_dataset',                                │
# │                                           'identifier': 'test_id',                                              │
# │                                           'session_start_time': datetime.datetime(2024, 12, 4, 14, 22, 19,      │
# │                                       529389, tzinfo=tzlocal()),                                                │
# │                                           'timestamps_reference_time': datetime.datetime(2024, 12, 4, 14, 22,   │
# │                                       19, 529389, tzinfo=tzlocal()),                                            │
# │                                           'file_create_date': [                                                 │
# │                                               datetime.datetime(2024, 12, 4, 14, 22, 19, 530293,                │
# │                                       tzinfo=tzlocal())                                                         │
# │                                           ],                                                                    │
# │                                           'related_publications': ('None',),                                    │
# │                                           'lab': 'Zimmer lab',                                                  │
# │                                           'institution': 'Univie',                                              │
# │                                           'acquisition': {},                                                    │
# │                                           'analysis': {},                                                       │
# │                                           'devices': {},                                                        │
# │                                           'electrode_groups': {},                                               │
# │                                           'icephys_electrodes': {},                                             │
# │                                           'imaging_planes': {},                                                 │
# │                                           'intervals': {},                                                      │
# │                                           'lab_meta_data': {},                                                  │
# │                                           'processing': {},                                                     │
# │                                           'ogen_sites': {},                                                     │
# │                                           'scratch': {},                                                        │
# │                                           'stimulus': {},                                                       │
# │                                           'stimulus_template': {}                                               │
# │                                       }                                                                         │
# │                    file_create_date = [datetime.datetime(2024, 12, 4, 14, 22, 19, 530293, tzinfo=tzlocal())]    │
# │                       ic_electrodes = {}                                                                        │
# │                  icephys_electrodes = {}                                                                        │
# │     icephys_experimental_conditions = None                                                                      │
# │                   icephys_filtering = None                                                                      │
# │                 icephys_repetitions = None                                                                      │
# │       icephys_sequential_recordings = None                                                                      │
# │     icephys_simultaneous_recordings = None                                                                      │
# │                          identifier = 'test_id'                                                                 │
# │                      imaging_planes = {}                                                                        │
# │                         institution = 'Univie'                                                                  │
# │                           intervals = {}                                                                        │
# │            intracellular_recordings = None                                                                      │
# │                       invalid_times = None                                                                      │
# │                           js_script = "\n        <script>\n            function copyToClipboard(text) {\n       │
# │                                       navigator.clipboard.writeText(text).then(function() {\n                   │
# │                                       console.log('Copied to clipboard: ' + text);\n                },          │
# │                                       function(err) {\n                    console.error('Could not copy text:  │
# │                                       ', err);\n                });\n            }\n\n                          │
# │                                       document.addEventListener('DOMContentLoaded', function() {\n              │
# │                                       let fieldKeys = document.querySelectorAll('.container-fields              │
# │                                       .field-key');\n                fieldKeys.forEach(function(fieldKey) {\n   │
# │                                       fieldKey.addEventListener('click', function() {\n                         │
# │                                       let accessCode = fieldKey.getAttribute('title').replace('Access code: ',  │
# │                                       '');\n                        copyToClipboard(accessCode);\n              │
# │                                       });\n                });\n            });\n        </script>\n        "   │
# │                            keywords = None                                                                      │
# │                                 lab = 'Zimmer lab'                                                              │
# │                       lab_meta_data = {}                                                                        │
# │                            modified = True                                                                      │
# │                             modules = {}                                                                        │
# │                                name = 'root'                                                                    │
# │                           namespace = 'core'                                                                    │
# │                      neurodata_type = 'NWBFile'                                                                 │
# │                               notes = None                                                                      │
# │                           object_id = '06292f92-c338-4c70-bce3-9fec32e1e4b6'                                    │
# │                             objects = {                                                                         │
# │                                           '06292f92-c338-4c70-bce3-9fec32e1e4b6': root pynwb.file.NWBFile at    │
# │                                       0x139527466928928                                                         │
# │                                       Fields:                                                                   │
# │                                         file_create_date: [datetime.datetime(2024, 12, 4, 14, 22, 19, 530293,   │
# │                                       tzinfo=tzlocal())]                                                        │
# │                                         identifier: test_id                                                     │
# │                                         institution: Univie                                                     │
# │                                         lab: Zimmer lab                                                         │
# │                                         related_publications: ['None']                                          │
# │                                         session_description: test_dataset                                       │
# │                                         session_start_time: 2024-12-04 14:22:19.529389+01:00                    │
# │                                         timestamps_reference_time: 2024-12-04 14:22:19.529389+01:00             │
# │                                                                                                                 │
# │                                       }                                                                         │
# │                          ogen_sites = {}                                                                        │
# │                              parent = None                                                                      │
# │                        pharmacology = None                                                                      │
# │                          processing = {}                                                                        │
# │                            protocol = None                                                                      │
# │                             read_io = None                                                                      │
# │                related_publications = ('None',)                                                                 │
# │                             scratch = {}                                                                        │
# │                 session_description = 'test_dataset'                                                            │
# │                          session_id = None                                                                      │
# │                  session_start_time = datetime.datetime(2024, 12, 4, 14, 22, 19, 529389, tzinfo=tzlocal())      │
# │                              slices = None                                                                      │
# │                       source_script = None                                                                      │
# │             source_script_file_name = None                                                                      │
# │                            stimulus = {}                                                                        │
# │                      stimulus_notes = None                                                                      │
# │                   stimulus_template = {}                                                                        │
# │                             subject = None                                                                      │
# │                             surgery = None                                                                      │
# │                         sweep_table = None                                                                      │
# │           timestamps_reference_time = datetime.datetime(2024, 12, 4, 14, 22, 19, 529389, tzinfo=tzlocal())      │
# │                              trials = None                                                                      │
# │                               units = None                                                                      │
# │                               virus = None                                                                      │
# │                     add_acquisition = def add_acquisition(*args, **kwargs): add_acquisition(nwbdata,            │
# │                                       use_sweep_table=False)                                                    │
# │                        add_analysis = def add_analysis(*args, **kwargs): add_analysis(analysis)                 │
# │                           add_child = def add_child(*args, **kwargs): add_child(child=None)                     │
# │                          add_device = def add_device(*args, **kwargs): add_device(devices)                      │
# │                       add_electrode = def add_electrode(*args, **kwargs): add_electrode(x=None, y=None, z=None, │
# │                                       imp=None, location=None, filtering=None, group=None, id=None, rel_x=None, │
# │                                       rel_y=None, rel_z=None, reference=None, enforce_unique_id=True)           │
# │                add_electrode_column = def add_electrode_column(*args, **kwargs): add_electrode_column(name,     │
# │                                       description, data=[], table=False, index=False, enum=False,               │
# │                                       col_cls=<class 'hdmf.common.table.VectorData'>, check_ragged=True)        │
# │                 add_electrode_group = def add_electrode_group(*args, **kwargs):                                 │
# │                                       add_electrode_group(electrode_groups)                                     │
# │                           add_epoch = def add_epoch(*args, **kwargs): add_epoch(start_time, stop_time,          │
# │                                       tags=None, timeseries=None)                                               │
# │                    add_epoch_column = def add_epoch_column(*args, **kwargs): add_epoch_column(name,             │
# │                                       description, data=[], table=False, index=False, enum=False,               │
# │                                       col_cls=<class 'hdmf.common.table.VectorData'>, check_ragged=True)        │
# │           add_epoch_metadata_column = def add_epoch_metadata_column(*args, **kwargs):                           │
# │                                       This method is deprecated and will be removed in future versions. Please  │
# │                                       use :py:meth:`~pynwb.file.NWBFile.add_epoch_column` instead               │
# │                    add_ic_electrode = def add_ic_electrode(*args, **kwargs):                                    │
# │                                       This method is deprecated and will be removed in future versions. Please  │
# │                                       use :py:meth:`~pynwb.file.NWBFile.add_icephys_electrode` instead          │
# │               add_icephys_electrode = def add_icephys_electrode(*args, **kwargs):                               │
# │                                       add_icephys_electrode(icephys_electrodes)                                 │
# │  add_icephys_experimental_condition = def add_icephys_experimental_condition(*args, **kwargs):                  │
# │                                       add_icephys_experimental_condition(repetitions=None)                      │
# │              add_icephys_repetition = def add_icephys_repetition(*args, **kwargs):                              │
# │                                       add_icephys_repetition(sequential_recordings=None)                        │
# │    add_icephys_sequential_recording = def add_icephys_sequential_recording(*args, **kwargs):                    │
# │                                       add_icephys_sequential_recording(stimulus_type, simultaneous_recordings)  │
# │  add_icephys_simultaneous_recording = def add_icephys_simultaneous_recording(*args, **kwargs):                  │
# │                                       add_icephys_simultaneous_recording(recordings)                            │
# │                   add_imaging_plane = def add_imaging_plane(*args, **kwargs): add_imaging_plane(imaging_planes) │
# │         add_intracellular_recording = def add_intracellular_recording(*args, **kwargs):                         │
# │                                       add_intracellular_recording(electrode=None, stimulus_start_index=None,    │
# │                                       stimulus_index_count=None, stimulus=None,                                 │
# │                                       stimulus_template_start_index=None, stimulus_template_index_count=None,   │
# │                                       stimulus_template=None, response_start_index=None,                        │
# │                                       response_index_count=None, response=None, electrode_metadata=None,        │
# │                                       stimulus_metadata=None, response_metadata=None)                           │
# │           add_invalid_time_interval = def add_invalid_time_interval(*args, **kwargs):                           │
# │                                       add_invalid_time_interval(start_time, stop_time, tags=None,               │
# │                                       timeseries=None)                                                          │
# │            add_invalid_times_column = def add_invalid_times_column(*args, **kwargs):                            │
# │                                       add_invalid_times_column(name, description, data=[], table=False,         │
# │                                       index=False, enum=False, col_cls=<class 'hdmf.common.table.VectorData'>,  │
# │                                       check_ragged=True)                                                        │
# │                   add_lab_meta_data = def add_lab_meta_data(*args, **kwargs): add_lab_meta_data(lab_meta_data)  │
# │                       add_ogen_site = def add_ogen_site(*args, **kwargs): add_ogen_site(ogen_sites)             │
# │               add_processing_module = def add_processing_module(*args, **kwargs):                               │
# │                                       add_processing_module(processing)                                         │
# │                         add_scratch = def add_scratch(*args, **kwargs): add_scratch(data, name=None,            │
# │                                       notes=None, table_description='', description=None)                       │
# │                        add_stimulus = def add_stimulus(*args, **kwargs): add_stimulus(stimulus=None,            │
# │                                       use_sweep_table=False, timeseries=None)                                   │
# │               add_stimulus_template = def add_stimulus_template(*args, **kwargs):                               │
# │                                       add_stimulus_template(timeseries, use_sweep_table=False)                  │
# │                  add_time_intervals = def add_time_intervals(*args, **kwargs): add_time_intervals(intervals)    │
# │                           add_trial = def add_trial(*args, **kwargs): add_trial(start_time, stop_time,          │
# │                                       tags=None, timeseries=None)                                               │
# │                    add_trial_column = def add_trial_column(*args, **kwargs): add_trial_column(name,             │
# │                                       description, data=[], table=False, index=False, enum=False,               │
# │                                       col_cls=<class 'hdmf.common.table.VectorData'>, check_ragged=True)        │
# │                            add_unit = def add_unit(*args, **kwargs): add_unit(spike_times=None,                 │
# │                                       obs_intervals=None, electrodes=None, electrode_group=None,                │
# │                                       waveform_mean=None, waveform_sd=None, waveforms=None, id=None)            │
# │                     add_unit_column = def add_unit_column(*args, **kwargs): add_unit_column(name, description,  │
# │                                       data=[], table=False, index=False, enum=False, col_cls=<class             │
# │                                       'hdmf.common.table.VectorData'>, check_ragged=True)                       │
# │                        all_children = def all_children(): Get a list of all child objects and their child       │
# │                                       objects recursively.                                                      │
# │                                copy = def copy():                                                               │
# │                                       Shallow copy of an NWB file.                                              │
# │                                       Useful for linking across files.                                          │
# │                       create_device = def create_device(*args, **kwargs): create_device(name, description=None, │
# │                                       manufacturer=None)                                                        │
# │              create_electrode_group = def create_electrode_group(*args, **kwargs): create_electrode_group(name, │
# │                                       description, location, device, position=None)                             │
# │       create_electrode_table_region = def create_electrode_table_region(*args, **kwargs):                       │
# │                                       create_electrode_table_region(region, description, name='electrodes')     │
# │                 create_ic_electrode = def create_ic_electrode(*args, **kwargs):                                 │
# │                                       This method is deprecated and will be removed in future versions. Please  │
# │                                       use :py:meth:`~pynwb.file.NWBFile.create_icephys_electrode` instead       │
# │            create_icephys_electrode = def create_icephys_electrode(*args, **kwargs):                            │
# │                                       create_icephys_electrode(name, device, description, slice=None,           │
# │                                       seal=None, location=None, resistance=None, filtering=None,                │
# │                                       initial_access_resistance=None, cell_id=None)                             │
# │                create_imaging_plane = def create_imaging_plane(*args, **kwargs): create_imaging_plane(name,     │
# │                                       optical_channel, description, device, excitation_lambda, indicator,       │
# │                                       location, imaging_rate=None, manifold=None, conversion=1.0,               │
# │                                       unit='meters', reference_frame=None, origin_coords=None,                  │
# │                                       origin_coords_unit='meters', grid_spacing=None,                           │
# │                                       grid_spacing_unit='meters')                                               │
# │                create_lab_meta_data = def create_lab_meta_data(*args, **kwargs): create_lab_meta_data(name)     │
# │                    create_ogen_site = def create_ogen_site(*args, **kwargs): create_ogen_site(name, device,     │
# │                                       description, excitation_lambda, location)                                 │
# │            create_processing_module = def create_processing_module(*args, **kwargs):                            │
# │                                       create_processing_module(name, description, data_interfaces=None)         │
# │               create_time_intervals = def create_time_intervals(*args, **kwargs): create_time_intervals(name,   │
# │                                       description='experimental intervals', id=None, columns=None,              │
# │                                       colnames=None)                                                            │
# │                     generate_new_id = def generate_new_id(*args, **kwargs): generate_new_id(recurse=True)       │
# │                     get_acquisition = def get_acquisition(*args, **kwargs): get_acquisition(name=None)          │
# │                        get_analysis = def get_analysis(*args, **kwargs): get_analysis(name=None)                │
# │                        get_ancestor = def get_ancestor(*args, **kwargs): get_ancestor(neurodata_type=None)      │
# │                       get_ancestors = def get_ancestors(*args, **kwargs): get_ancestors()                       │
# │                          get_device = def get_device(*args, **kwargs): get_device(name=None)                    │
# │                 get_electrode_group = def get_electrode_group(*args, **kwargs): get_electrode_group(name=None)  │
# │                     get_fields_conf = def get_fields_conf():                                                    │
# │                    get_ic_electrode = def get_ic_electrode(*args, **kwargs):                                    │
# │                                       This method is deprecated and will be removed in future versions. Please  │
# │                                       use :py:meth:`~pynwb.file.NWBFile.get_icephys_electrode` instead          │
# │               get_icephys_electrode = def get_icephys_electrode(*args, **kwargs):                               │
# │                                       get_icephys_electrode(name=None)                                          │
# │ get_icephys_experimental_conditions = def get_icephys_experimental_conditions(*args, **kwargs):                 │
# │                                       get_icephys_experimental_conditions()                                     │
# │       get_icephys_meta_parent_table = def get_icephys_meta_parent_table(): Get the top-most table in the        │
# │                                       intracellular ephys metadata table hierarchy that exists in this NWBFile. │
# │             get_icephys_repetitions = def get_icephys_repetitions(*args, **kwargs): get_icephys_repetitions()   │
# │   get_icephys_sequential_recordings = def get_icephys_sequential_recordings(*args, **kwargs):                   │
# │                                       get_icephys_sequential_recordings()                                       │
# │ get_icephys_simultaneous_recordings = def get_icephys_simultaneous_recordings(*args, **kwargs):                 │
# │                                       get_icephys_simultaneous_recordings()                                     │
# │                   get_imaging_plane = def get_imaging_plane(*args, **kwargs): get_imaging_plane(name=None)      │
# │        get_intracellular_recordings = def get_intracellular_recordings(*args, **kwargs):                        │
# │                                       get_intracellular_recordings()                                            │
# │                   get_lab_meta_data = def get_lab_meta_data(*args, **kwargs): get_lab_meta_data(name=None)      │
# │                get_linked_resources = def get_linked_resources():                                               │
# │                       get_ogen_site = def get_ogen_site(*args, **kwargs): get_ogen_site(name=None)              │
# │               get_processing_module = def get_processing_module(*args, **kwargs):                               │
# │                                       get_processing_module(name=None)                                          │
# │                         get_read_io = def get_read_io(): Get the io object used to read this container.         │
# │                         get_scratch = def get_scratch(*args, **kwargs): get_scratch(name, convert=True)         │
# │                        get_stimulus = def get_stimulus(*args, **kwargs): get_stimulus(name=None)                │
# │               get_stimulus_template = def get_stimulus_template(*args, **kwargs):                               │
# │                                       get_stimulus_template(name=None)                                          │
# │                  get_time_intervals = def get_time_intervals(*args, **kwargs): get_time_intervals(name=None)    │
# │                      link_resources = def link_resources(*args, **kwargs): link_resources(herd)                 │
# │                        reset_parent = def reset_parent(): Reset the parent of this Container to None and remove │
# │                                       the Container from the children of its parent.                            │
# │                         set_data_io = def set_data_io(dataset_name: str, data_io_class:                         │
# │                                       Type[hdmf.data_utils.DataIO], data_io_kwargs: dict = None,                │
# │                                       data_chunk_iterator_class:                                                │
# │                                       Optional[Type[hdmf.data_utils.AbstractDataChunkIterator]] = None,         │
# │                                       data_chunk_iterator_kwargs: dict = None, **kwargs): Apply DataIO object   │
# │                                       to a dataset field of the Container.                                      │
# │                 set_electrode_table = def set_electrode_table(*args, **kwargs):                                 │
# │                                       set_electrode_table(electrode_table)                                      │
# │                        set_modified = def set_modified(*args, **kwargs): set_modified(modified=True)            │
# │                      type_hierarchy = def type_hierarchy():                                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
inspect(nwb_test.add_device, methods=True)
# Out:
# ╭─ <bound method docval.<locals>.dec.<locals>.func_call of root pynwb.file.NWBFile at 0x139527466928928 Fields:  ─╮
# │ def docval.<locals>.dec.<locals>.func_call(*args, **kwargs):                                                    │
# │                                                                                                                 │
# │ add_device(devices)                                                                                             │
# │                                                                                                                 │
# │ 29 attribute(s) not shown. Run inspect(inspect) for options.                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
